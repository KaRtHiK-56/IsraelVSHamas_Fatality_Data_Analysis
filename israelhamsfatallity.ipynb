# %% [markdown]
# <a href="https://colab.research.google.com/github/KaRtHiK-56/IsraelVSHamas_Fatality_Data_Analysis/blob/main/israelhamsfatallity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**INTRODUCTION**
# This dataset provides information on the individuals killed during the Israeli-Palestinian conflict since the second intifada, which began in September 2000. The data has been meticulously collected and investigated by B’Tselem – The Israeli Information Center for Human Rights in the Occupied Territories.
#
# The dataset includes statistics on all human beings – Palestinians, Israelis, and foreign nationals – who lost their lives during this conflict. It provides details such as name, age, citizenship, date of death, gender, participation in hostilities, place of residence, type of injury, ammunition used, and more.

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv('fatalities_i_p.csv')
data
# Out:
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district  \
# ...

# %%
#seeing the dimentions of dataset
print('The dimentionality of this data is')
data.shape
# Out:
# The dimentionality of this data is
# (11124, 16)

# %%
#no. of elements in dataset
print('The number of elements in the data is')
data.size
# Out:
# The number of elements in the data is
# 177984

# %%
#information of the dataset
print('This is the information about the data')
data.info()
# Out:
# This is the information about the data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11124 entries, 0 to 11123
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          11124 non-null  object
#  1   date_of_event                 11124 non-null  object
#  2   age                           10995 non-null  float64
#  3   citizenship                   11124 non-null  object
#  4   event_location                11124 non-null  object
#  5   event_location_district       11124 non-null  object
#  6   event_location_region         11124 non-null  object
#  7   date_of_death                 11124 non-null  object
#  8   gender                        11104 non-null  object
#  9   took_part_in_the_hostilities  9694 non-null   object
#  10  place_of_residence            11056 non-null  object
#  11  place_of_residence_district   11056 non-null  object
# ...

# %%
#statistical summary
print('The statistical summary of the data')
data.describe()
# Out:
# The statistical summary of the data
#                 age
# count  10995.000000
# mean      26.745703
# std       13.780548
# min        1.000000
# 25%       19.000000
# 50%       23.000000
# 75%       31.000000
# max      112.000000

# %%
#column names
print('The features of the data are')
data.columns
# Out:
# The features of the data are
# Index(['name', 'date_of_event', 'age', 'citizenship', 'event_location',
#        'event_location_district', 'event_location_region', 'date_of_death',
#        'gender', 'took_part_in_the_hostilities', 'place_of_residence',
#        'place_of_residence_district', 'type_of_injury', 'ammunition',
#        'killed_by', 'notes'],
#       dtype='object')

# %%
#coulmn datatypes
print('The datatypes of the features')
data.dtypes
# Out:
# The datatypes of the features
# name                             object
# date_of_event                    object
# age                             float64
# citizenship                      object
# event_location                   object
# event_location_district          object
# event_location_region            object
# date_of_death                    object
# gender                           object
# took_part_in_the_hostilities     object
# place_of_residence               object
# place_of_residence_district      object
# type_of_injury                   object
# ammunition                       object
# killed_by                        object
# notes                            object
# dtype: object

# %%
#checking for the missing values
print('These all are the missing values in the data')
data.isnull().sum()
# Out:
# These all are the missing values in the data
# name                               0
# date_of_event                      0
# age                              129
# citizenship                        0
# event_location                     0
# event_location_district            0
# event_location_region              0
# date_of_death                      0
# gender                            20
# took_part_in_the_hostilities    1430
# place_of_residence                68
# place_of_residence_district       68
# type_of_injury                   291
# ammunition                      5253
# killed_by                          0
# notes                            280
# dtype: int64

# %%
#seeing unique values of each categorical feature
print('Citizenship',data['citizenship'].unique())
print('Gender',data['gender'].unique())
print('Hostile',data['took_part_in_the_hostilities'].unique())
print('Injury',data['type_of_injury'].unique())
print('Killed by',data['killed_by'].unique())
# Out:
# Citizenship ['Palestinian' 'Israeli' 'Jordanian' 'American']
# Gender ['M' 'F' nan]
# Hostile [nan 'No' 'Yes' 'Unknown' 'Israelis' 'Object of targeted killing']
# Injury ['gunfire' 'stabbing' 'hit by a vehicle' 'explosion' 'physical assault'
#  'shelling' 'being bludgeoned with an axe' 'physically assaulted'
#  'beating' 'stones throwing' 'Strangulation' nan 'fire' 'house demolition']
# Killed by ['Israeli security forces' 'Palestinian civilians' 'Israeli civilians']

# %%
#duplicated value datas
data[data.duplicated()]
# Out:
#                            name date_of_event  age  citizenship  \
# 9373   Name unknown to B'Tselem    2003-01-13  NaN  Palestinian
# 9985   Name unknown to B'Tselem    2002-05-05  NaN  Palestinian
# 9986   Name unknown to B'Tselem    2002-05-05  NaN  Palestinian
# 10234  Name unknown to B'Tselem    2002-04-01  NaN  Palestinian
# 10817  Name unknown to B'Tselem    2001-12-02  NaN  Palestinian
# 10818  Name unknown to B'Tselem    2001-12-02  NaN  Palestinian
# 10824  Name unknown to B'Tselem    2001-12-02  NaN  Palestinian
#
#          event_location event_location_district event_location_region  \
# 9373            Nitzana                  Israel                Israel
# 9985   Karni Checkpoint                    Gaza            Gaza Strip
# 9986           Kissufim              Khan Yunis            Gaza Strip
# 10234        Jenin R.C.                   Jenin             West Bank
# 10817             Jenin                   Jenin             West Bank
# ...

# %%
#deleting the duplicated values
print('Dropping the duplicated values since these are similar in values')
data.drop_duplicates()
# Out:
# Dropping the duplicated values since these are similar in values
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
# ...

# %% [markdown]
# ##OBSERVATONS
# 1. The dimentionality of this data is (11124, 16).
# 2. The number of elements in the data is 177984.
# 3. 8 features in the data has missing values that needs to be treated.
# 4. There were 7 duplicate values in the data as it produce skewed result and it was removed.
# 5. The data has only 1 numeric value that is age.

# %% [markdown]
# #EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ###PLAN OF ATTACK
# 1. Missing value
# 2. Categorical varibale (encoding)
# 3. plotting

# %% [markdown]
# ###Goals
# UNIVARIATE ANALYSIS
# 1. Time series of the timeline
# 2. Distribution of the age
# 3. citizenship's countplot/pie
# 4. map of the locations
# 5. gender countplot/pie
# 6. who were more hostiles count/pie
# 7. type of injury count/pie
# 8. ammunation count/pie
# 9. who killed the most count/pie
# 10. world cloud on notes notes
#
# BIVARIATE ANALYSIS
# 1. age vs gender

# %%
data.isnull().sum()
# Out:
# name                               0
# date_of_event                      0
# age                              129
# citizenship                        0
# event_location                     0
# event_location_district            0
# event_location_region              0
# date_of_death                      0
# gender                            20
# took_part_in_the_hostilities    1430
# place_of_residence                68
# place_of_residence_district       68
# type_of_injury                   291
# ammunition                      5253
# killed_by                          0
# notes                            280
# dtype: int64

# %%
sns.boxplot(data['age'])
# Out:
# <Axes: >

# %%
px.histogram(data,x=data['age'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The data is right skewed

# %%
print('the mean of the age is', data.mean())
print('the median of the age is', data.median())
# Out:
# the mean of the age is age    26.745703
# dtype: float64
# the median of the age is age    23.0
# dtype: float64
# <ipython-input-90-bce736e647ab>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-90-bce736e647ab>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
print('The maximum age reported',data['age'].max())
print('The minimum age reported',data['age'].min())
# Out:
# The maximum age reported 112.0
# The minimum age reported 1.0

# %%
#replacing the age with mean value as the average life span of real life people is around 75 to 80
data['age'] = data['age'].fillna(data['age'].mean())

# %%
data['age'].isnull().sum()
# Out:
# 0

# %%
upper_limit = data['age'].mean() + 3.5*data['age'].std()
lower_limit = data['age'].mean() - 3*data['age'].std()
print(upper_limit)
print(lower_limit)
# Out:
# 74.69711642524287
# -14.355509264903159

# %%
data['age'] = np.where(
data['age'] > upper_limit,upper_limit,
np.where(data['age'] < lower_limit,lower_limit,data['age']))

# %%
sns.boxplot(data['age'])
# Out:
# <Axes: >

# %%
px.histogram(data,x=data['age'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##DATA VISUALIZATION

# %%
data
# Out:
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district  \
# ...

# %%
data['date_of_event'] = pd.to_datetime(data['date_of_event'])
data['date_of_death'] = pd.to_datetime(data['date_of_death'])

# %%
px.pie(data['citizenship'],names=data['citizenship'],title='Types of citizenship')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
citizenship = data['citizenship'].value_counts()
citizenship = pd.DataFrame(citizenship)
citizenship
# Out:
#              citizenship
# Palestinian        10092
# Israeli             1029
# Jordanian              2
# American               1

# %%
citizenship.plot(kind='bar')
# Out:
# <Axes: >

# %%
px.scatter_geo(data,locations=data["event_location"],locationmode='country names',projection="natural earth")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter_geo(data,locations=data["event_location_district"],locationmode='country names',projection="natural earth")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gender = data['gender'].value_counts()
gender = pd.DataFrame(gender)
gender
# Out:
#    gender
# M    9681
# F    1423

# %%
gender.plot(kind='pie',subplots=True)
# Out:
# array([<Axes: ylabel='gender'>], dtype=object)

# %%
hostile = data['took_part_in_the_hostilities'].value_counts()
hostile = pd.DataFrame(hostile)
hostile
# Out:
#                             took_part_in_the_hostilities
# No                                                  4653
# Yes                                                 3467
# Israelis                                             771
# Unknown                                              603
# Object of targeted killing                           200

# %%
hostile.plot(kind='bar')
# Out:
# <Axes: >

# %%
injury = data['type_of_injury'].value_counts()
injury = pd.DataFrame(injury)
injury
# Out:
#                               type_of_injury
# gunfire                                 9849
# explosion                                555
# shelling                                 311
# stabbing                                  48
# house demolition                          25
# hit by a vehicle                          18
# beating                                    9
# stones throwing                            6
# being bludgeoned with an axe               4
# fire                                       4
# physically assaulted                       2
# physical assault                           1
# Strangulation                              1

# %%
injury.plot(kind='bar')
# Out:
# <Axes: >

# %%
ammunation = data['ammunition'].value_counts()
ammunation = pd.DataFrame(ammunation)
ammunation
# Out:
#                              ammunition
# missile                            2877
# live ammunition                    1514
# shell                               675
# explosive belt                      326
# bomb                                249
# mortar fire                          51
# knife                                37
# flechette shells                     22
# rubber-coated metal bullets          19
# 0.22-caliber bullets                 16
# phosphorus shell                     16
# Qassam rocket                        15
# car bomb                             15
# teargas canister                     13
# rocket                               12
# grad rocket                           7
# sponge rounds                         2
# grenade                               2
# flare bomb                            1
# stun grenade                          1
# rock                                  1

# %%
ammunation.plot(kind='bar')
# Out:
# <Axes: >

# %%
kills = data['killed_by'].value_counts()
kills = pd.DataFrame(kills)
kills
# Out:
#                          killed_by
# Israeli security forces      10000
# Palestinian civilians         1028
# Israeli civilians               96

# %%
kills.plot(kind='pie',subplots=True)
# Out:
# array([<Axes: ylabel='killed_by'>], dtype=object)

# %%
location = data['event_location'].value_counts()
location = pd.DataFrame(location)
location = location.head(50)
location
# Out:
#                                  event_location
# Gaza City                                  2232
# Rafah                                       832
# Khan Yunis                                  538
# Jabalya R.C.                                477
# Beit Lahiya                                 471
# Jabalya                                     411
# Beit Hanoun                                 409
# Nablus                                      293
# al-Bureij R.C.                              240
# Deir al-Balah                               220
# Jerusalem                                   194
# Khuza'ah                                    178
# Jenin                                       169
# Jenin R.C.                                  165
# al-Qararah                                  142
# a-Nuseirat R.C.                             139
# Hebron                                      135
# Bani Suheila                                130
# 'Abasan al-Kabirah                          115
# ...

# %%
location.plot(kind='bar')
# Out:
# <Axes: >

# %%
dist = data['event_location_district'].value_counts()
dist = pd.DataFrame(dist)
dist
# Out:
#                       event_location_district
# Gaza                                     2435
# North Gaza                               1910
# Khan Yunis                               1394
# Rafah                                    1066
# Deir al-Balah                             854
# Israel                                    679
# Nablus                                    647
# Jenin                                     512
# Ramallah and al-Bira                      350
# Hebron                                    347
# Tulkarm                                   254
# Bethlehem                                 186
# East Jerusalem                            130
# al-Quds                                    85
# Gush Katif                                 70
# Qalqiliya                                  65
# Tubas                                      52
# Jericho                                    48
# Salfit                                     36
# ...

# %%
dist.plot(kind='bar')
# Out:
# <Axes: >

# %%
region = data['event_location_region'].value_counts()
region = pd.DataFrame(region)
region
# Out:
#             event_location_region
# Gaza Strip                   7733
# West Bank                    2712
# Israel                        679

# %%
region.plot(kind='pie',subplots=True)
# Out:
# array([<Axes: ylabel='event_location_region'>], dtype=object)

# %%
data['notes'] = data['notes'].astype(str)

# %%
notes = data['notes']
notes
# Out:
# 0        Fatally shot by Israeli forces while standing ...
# 1        Fatally shot by Israeli forces while trying to...
# 2        Fatally shot by soldiers while firing at them ...
# 3        Shot in the head by Israeli forces while throw...
# 4        Wounded by soldiers’ gunfire after running awa...
#                                ...
# 11119                    Killed while hiking on Mt. Eival.
# 11120    Killed by a settler from Itamar while harvesti...
# 11121       His body was found a day after he disappeared.
# 11122     Killed by settlers who rioted in Biddya village.
# 11123                                                  nan
# Name: notes, Length: 11124, dtype: object

# %%
import nltk
from wordcloud import WordCloud
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopword = stopwords.words('english')
stopword
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
wc = WordCloud(collocations=False)
text = " ".join(words for words in notes if not words in stopwords.words('english'))
wc.generate(text)
plt.imshow(wc,interpolation='bilinear')
plt.show()

# %%
events = data.groupby(['date_of_event']).size()
events
# Out:
# date_of_event
# 2000-10-02    1
# 2000-10-07    2
# 2000-10-17    1
# 2000-10-19    1
# 2000-10-27    1
#              ..
# 2023-09-09    1
# 2023-09-19    5
# 2023-09-20    1
# 2023-09-22    1
# 2023-09-24    2
# Length: 2405, dtype: int64

# %%
px.line(events,title='Timeline of event occured')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
deaths = data.groupby(['date_of_death']).size()
deaths
# Out:
# date_of_death
# 2000-10-02    1
# 2000-10-07    2
# 2000-10-17    1
# 2000-10-19    1
# 2000-10-27    1
#              ..
# 2023-09-09    1
# 2023-09-19    4
# 2023-09-20    2
# 2023-09-22    1
# 2023-09-24    2
# Length: 2593, dtype: int64

# %%
px.line(deaths,title='Timeline of deaths occured')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data['year'] = data['date_of_event'].dt.year
data
# Out:
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11124 entries, 0 to 11123
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          11124 non-null  object
#  1   date_of_event                 11124 non-null  datetime64[ns]
#  2   age                           11124 non-null  float64
#  3   citizenship                   11124 non-null  object
#  4   event_location                11124 non-null  object
#  5   event_location_district       11124 non-null  object
#  6   event_location_region         11124 non-null  object
#  7   date_of_death                 11124 non-null  datetime64[ns]
#  8   gender                        11104 non-null  object
#  9   took_part_in_the_hostilities  9694 non-null   object
#  10  place_of_residence            11056 non-null  object
#  11  place_of_residence_district   11056 non-null  object
# ...

# %%
y23 = (data['year'] == 2023)
data[y23]
# Out:
#                                             name date_of_event   age  \
# 0    'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1           Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2               'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3               Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                   Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ..                                           ...           ...   ...
# 244                   'Amer Ghazi Mahmoud Zaytun    2023-01-05  16.0
# 245                     Adam 'Issam Shaker 'Ayad    2023-01-03  15.0
# 246               Muhammad Samer Hassan Hushiyeh    2023-01-02  21.0
# 247                Yazan Samer 'Izzat al-Ja'bari    2023-01-01  19.0
# 248                    Fouad Mahmoud Ahmad A'bed    2023-01-01  17.0
#
#      citizenship     event_location event_location_district  \
# 0    Palestinian     Nur Shams R.C.                 Tulkarm
# ...

# %%
events23 = data[y23].groupby(['date_of_event']).size()
events23
# Out:
# date_of_event
# 2023-01-01    2
# 2023-01-02    1
# 2023-01-03    1
# 2023-01-05    1
# 2023-01-11    3
#              ..
# 2023-09-09    1
# 2023-09-19    5
# 2023-09-20    1
# 2023-09-22    1
# 2023-09-24    2
# Length: 102, dtype: int64

# %%
px.line(events23,title='Timeline of events occured in 2023')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
d23 = (data['year'] == 2023)
data[d23]
# Out:
#                                             name date_of_event   age  \
# 0    'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1           Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2               'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3               Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                   Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ..                                           ...           ...   ...
# 244                   'Amer Ghazi Mahmoud Zaytun    2023-01-05  16.0
# 245                     Adam 'Issam Shaker 'Ayad    2023-01-03  15.0
# 246               Muhammad Samer Hassan Hushiyeh    2023-01-02  21.0
# 247                Yazan Samer 'Izzat al-Ja'bari    2023-01-01  19.0
# 248                    Fouad Mahmoud Ahmad A'bed    2023-01-01  17.0
#
#      citizenship     event_location event_location_district  \
# 0    Palestinian     Nur Shams R.C.                 Tulkarm
# ...

# %%
deaths23 = data[d23].groupby(['date_of_death']).size()
deaths23
# Out:
# date_of_death
# 2023-01-02    2
# 2023-01-03    1
# 2023-01-05    1
# 2023-01-11    2
# 2023-01-12    3
#              ..
# 2023-09-09    1
# 2023-09-19    4
# 2023-09-20    2
# 2023-09-22    1
# 2023-09-24    2
# Length: 102, dtype: int64

# %%
px.line(deaths23,title='Timeline of deaths occured in 2023')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(data['date_of_death'].dtype)
print(data['date_of_event'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
data.corr()
# Out:
# <ipython-input-140-c44ded798807>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#            age      year
# age   1.000000 -0.023067
# year -0.023067  1.000000

# %%
data.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
# Out:
#                                   name  date_of_event       age  citizenship  \
# name                          1.000000       0.977155 -0.014374     0.244131
# date_of_event                 0.977155       1.000000  0.004289     0.272378
# age                          -0.014374       0.004289  1.000000     0.090342
# citizenship                   0.244131       0.272378  0.090342     1.000000
# event_location                0.264482       0.299361 -0.009967     0.355196
# event_location_district      -0.051451      -0.035807  0.016678    -0.024180
# event_location_region        -0.008292      -0.030481  0.112094     0.264192
# date_of_death                 0.980384       0.999495  0.004113     0.268858
# gender                       -0.034871      -0.022353  0.227629     0.184543
# took_part_in_the_hostilities  0.491907       0.508560 -0.042570     0.403108
# place_of_residence            0.176044       0.201372  0.044056     0.498949
# ...

# %% [markdown]
# ##OBSERVATIONS
# 1. Age has some missing values so basically outlier detection is done and there were many outliers present in the age column and the maximum limit of the age was 50 and treating the outliers were done
# 2. Most of the people who got involed in this events are Palestine who are around 91% and followed by Isralies with 9%
# 3. Male ratio is more when compared to female that is 87% are male
# 4. Gunfire followed by explosion, shelling, stabbing, house demolotion were few of the types how people were killed
# 5. Missile, live ammunation,shelling,expllosives, and bombs are widly used for attacking.
# 6. Since Palestine attacked the isralies at first by some palestien citizen, to retaliate attacks were done in large scale by israel security forces and few by isralien citizens
# 7. Gaza, Rafah, and Khan yunis are the top 3 most attacked cities in this war.
# 8. In 2008, Israel launched a military campaign in the Gaza Strip called Operation Cast Lead. The campaign lasted 22 days and was codenamed Operation Cast Lead. The goal of the campaign was to stop Hamas rocket attacks on southern Israel and arms smuggling into Gaza.The Gaza War took place from December 2008 to January 2009. It was one of three major escalations between Israel and armed Palestinian groups in Gaza.
# 9. The 2014 Gaza War, also known as Operation Protective Edge, was a military operation launched by Israel on July 8, 2014. The war lasted 50 days, ending on August 26, 2014 with a ceasefire brokered by Egypt.
# 10. There is strong relationship between event and death as observed in the charts and it is also analysed in correlation section too.

# %% [markdown]
# #CONCLUSION
# By Summarizing the total collateral damage between Israel and Palestine
#
# 1.Over 120511 Palestine people and 10721 Israelis got injured in total of 131232 from 2000 to 2021 excluding the current year 2023
#
# 2.Over 10000 Palestine people and 1275 Israelis got killed in total of 11275 from 2000 to 2021 excluding the current year 2023
#
# 3.Total casualties that got affected due to this collateral damage are 142507
#
# 4.In 2023, as reported till 21-10-2023, over 4,385 dead with 13,651 injured.
#
# Finally resulting in innocent people are killed in the Israeli–Palestinian conflict because rockets are launched from Gaza at innocent civilians in Israel. Israel has a duty to protect its people from “Palestinian” settler-colonialist aggression; As Israel also annoucing war against Palestine causing innocent people getting killed,many missing their family and making thier daily life harder and impossible to live.
#
# In recent years, the conflict has escalated, with both Israel and the Palestinians taking steps that have made a two-state solution seem more and more elusive. In 2023, the Israeli government passed a law that would officially annex parts of the West Bank, a move that was widely condemned by the international community.
#
# The future of the Israeli-Palestinian conflict is uncertain. Both sides appear to be entrenched in their positions, and it is difficult to see how a peaceful solution can be reached. However, it is important to remember that violence will not solve anything. Only through dialogue and compromise can a lasting peace be achieved.
#
# Here are some possible solutions to the Israeli-Palestinian conflict:
#
# Two-state solution:
#
# This solution would involve the creation of an independent Palestinian state alongside Israel. This is the solution that has been endorsed by the international community, but it is becoming increasingly difficult to achieve.
#
# One-state solution:
#
# This solution would involve the creation of a single state in which Israelis and Palestinians would live together as equal citizens. This solution is opposed by many Israelis, but it may be the only viable option if a two-state solution is not possible.
#
# Confederation:
#
# This solution would involve the creation of a confederation between Israel and a future Palestinian state. This would allow the two states to cooperate on issues such as security and trade, while maintaining their independence. No matter what solution is ultimately reached, it will be clear that the Israeli-Palestinian conflict is a problem that can only be solved through dialogue and compromise. Violence will only make the situation worse.
